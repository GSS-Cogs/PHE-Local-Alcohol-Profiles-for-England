# %%
from gssutils import *
import requests

scraper = Scraper('https://www.gov.uk/government/collections/local-alcohol-profiles-for-england-lape')
scraper
# Out:
# ## Local Alcohol Profiles for England (LAPE)
#
# This is a catalog of datasets; choose one from the following:
#
# * Local Alcohol Profiles for England: February 2019 data update
# * Local Alcohol Profiles for England: December 2018 data update
# * Local Alcohol Profiles for England: September 2018 update
# * Local Alcohol Profiles for England: July 2018 update
# * Local Alcohol Profiles for England: February 2018 update
# * Local Alcohol Profiles for England: November 2017 update
# * Local Alcohol Profiles for England: May 2017 data update
# * Local Alcohol Profiles for England: March 2017 data update
# * Local Alcohol Profiles for England (LAPE): February 2017 data update
# * Local Alcohol Profiles for England: hospital admissions indicators, 2016 annual data update
# * Local Alcohol Profiles for England: mortality indicators, 2016 annual data update
# * Local Alcohol Profiles for England: 2015 annual data update
# * Local Alcohol Profiles for England: April 2014 annual data update

# %%
scraper.select_dataset(latest=True)
scraper
# Out:
# ## Local Alcohol Profiles for England: February 2019 data update
#
# Update of Indicators in the Local Alcohol Profiles for England (LAPE) interactive tool.
#
# ### Description
#
# Public Health England (PHE) has published an update to [Local Alcohol Profiles
# for England (LAPE)](http://fingertips.phe.org.uk/profile/local-alcohol-
# profiles).
#
# The LAPE interactive tool presents a range of alcohol-related indicators and
# allows users to view and analyse data in a user-friendly format.
#
# The aim of the profile is to provide information for local government, health
# organisations, commissioners and other agencies to monitor the impact of
# alcohol on local communities, and to monitor the services and initiatives that
# have been put in place to prevent and reduce the harmful impact of alcohol.
#
# This release includes an update of 13 alcohol-specific and alcohol-related
# hospital admissions indicators and further data breakdowns by age group and
# condition.
#
# [View previous Local Alcohol Profiles for England
# updates](https://www.gov.uk/government/collections/local-alcohol-profiles-for-
# england-lape)
#
# Relevant information from LAPE to aid in the understanding of alcohol-related
# harm in a local population is available from the [UK Government Web
# Archive](http://webarchive.nationalarchives.gov.uk/20171107173418/http://www.lape.org.uk/).
#
#   *[PHE]: Public Health England
#   *[LAPE]: Local alcohol profiles for England
#
#
#
# ### Distributions
#
# 1. Local Alcohol Profiles for England ([None](http://fingertips.phe.org.uk/profile/local-alcohol-profiles))
# 1. Local Alcohol Profiles for England: short statistical commentary, February 2019 ([None](https://www.gov.uk/government/publications/local-alcohol-profiles-for-england-february-2019-data-update/local-alcohol-profiles-for-england-short-statistical-commentary-february-2019))
# 1. Local Alcohol Profiles for England: short commentary slideset, February 2019 ([None](https://www.slideshare.net/PublicHealthEngland/local-alcohol-profiles-for-england-february-2019))
# 1. Pre-release access list: LAPE update, February 2019 ([None](https://www.gov.uk/government/publications/local-alcohol-profiles-for-england-february-2019-data-update/pre-release-access-list-lape-update-february-2019))

# %%
dist = scraper.distribution(title='Local Alcohol Profiles for England')
dist
# Out:
# <h3>Distribution</h3>
# <dl><dt>dct:title</dt><dd>&quot;Local Alcohol Profiles for England&quot;@en</dd>
# <dt>dcat:downloadURL</dt><dd><a href=http://fingertips.phe.org.uk/profile/local-alcohol-profiles>&lt;http://fingertips.phe.org.uk/profile/local-alcohol-profiles&gt;</a></dd>
# <dt>dcat:mediaType</dt><dd>&quot;None&quot;</dd>
# </dl>

# %%
dist.downloadURL = 'https://fingertipsws.phe.org.uk/api/all_data/csv/' + \
    'by_profile_id?parent_area_code=e92000001&parent_area_type_id=6&child_area_type_id=102&profile_id=87'
dist.mediaType = 'text/csv'

from io import BytesIO
table = pd.read_csv(BytesIO(scraper.session.get(dist.downloadURL, verify=False).content))
table
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
#         Indicator ID                                     Indicator Name  \
# 0              91414  10.01 - Admission episodes for alcohol-related...
# 1              91414  10.01 - Admission episodes for alcohol-related...
# 2              91414  10.01 - Admission episodes for alcohol-related...
# 3              91414  10.01 - Admission episodes for alcohol-related...
# 4              91414  10.01 - Admission episodes for alcohol-related...
# 5              91414  10.01 - Admission episodes for alcohol-related...
# 6              91414  10.01 - Admission episodes for alcohol-related...
# 7              91414  10.01 - Admission episodes for alcohol-related...
# 8              91414  10.01 - Admission episodes for alcohol-related...
# 9              91414  10.01 - Admission episodes for alcohol-related...
# 10             91414  10.01 - Admission episodes for alcohol-related...
# 11             91414  10.01 - Admission episodes for alcohol-related...
# 12             91414  10.01 - Admission episodes for alcohol-related...
# 13             91414  10.01 - Admission episodes for alcohol-related...
# 14             91414  10.01 - Admission episodes for alcohol-related...
# 15             91414  10.01 - Admission episodes for alcohol-related...
# 16             91414  10.01 - Admission episodes for alcohol-related...
# 17             91414  10.01 - Admission episodes for alcohol-related...
# 18             91414  10.01 - Admission episodes for alcohol-related...
# 19             91414  10.01 - Admission episodes for alcohol-related...
# 20             91414  10.01 - Admission episodes for alcohol-related...
# 21             91414  10.01 - Admission episodes for alcohol-related...
# 22             91414  10.01 - Admission episodes for alcohol-related...
# 23             91414  10.01 - Admission episodes for alcohol-related...
# 24             91414  10.01 - Admission episodes for alcohol-related...
# 25             91414  10.01 - Admission episodes for alcohol-related...
# 26             91414  10.01 - Admission episodes for alcohol-related...
# 27             91414  10.01 - Admission episodes for alcohol-related...
# 28             91414  10.01 - Admission episodes for alcohol-related...
# 29             91414  10.01 - Admission episodes for alcohol-related...
# ...              ...                                                ...
# 104150         93193           20.01 - Percentage of dependent drinkers
# 104151         93193           20.01 - Percentage of dependent drinkers
# 104152         93193           20.01 - Percentage of dependent drinkers
# 104153         93193           20.01 - Percentage of dependent drinkers
# 104154         93193           20.01 - Percentage of dependent drinkers
# 104155         93193           20.01 - Percentage of dependent drinkers
# 104156         93193           20.01 - Percentage of dependent drinkers
# 104157         93193           20.01 - Percentage of dependent drinkers
# 104158         93193           20.01 - Percentage of dependent drinkers
# 104159         93193           20.01 - Percentage of dependent drinkers
# 104160         93193           20.01 - Percentage of dependent drinkers
# 104161         93193           20.01 - Percentage of dependent drinkers
# 104162         93193           20.01 - Percentage of dependent drinkers
# 104163         93193           20.01 - Percentage of dependent drinkers
# 104164         93193           20.01 - Percentage of dependent drinkers
# 104165         93193           20.01 - Percentage of dependent drinkers
# 104166         93193           20.01 - Percentage of dependent drinkers
# 104167         93193           20.01 - Percentage of dependent drinkers
# 104168         93193           20.01 - Percentage of dependent drinkers
# 104169         93193           20.01 - Percentage of dependent drinkers
# 104170         93193           20.01 - Percentage of dependent drinkers
# 104171         93193           20.01 - Percentage of dependent drinkers
# 104172         93193           20.01 - Percentage of dependent drinkers
# 104173         93193           20.01 - Percentage of dependent drinkers
# 104174         93193           20.01 - Percentage of dependent drinkers
# 104175         93193           20.01 - Percentage of dependent drinkers
# 104176         93193           20.01 - Percentage of dependent drinkers
# 104177         93193           20.01 - Percentage of dependent drinkers
# 104178         93193           20.01 - Percentage of dependent drinkers
# 104179         93193           20.01 - Percentage of dependent drinkers
#
#        Parent Code                      Parent Name  Area Code  \
# 0              NaN                              NaN  E92000001
# 1              NaN                              NaN  E92000001
# 2              NaN                              NaN  E92000001
# 3              NaN                              NaN  E92000001
# 4              NaN                              NaN  E92000001
# 5              NaN                              NaN  E92000001
# 6              NaN                              NaN  E92000001
# 7              NaN                              NaN  E92000001
# 8              NaN                              NaN  E92000001
# 9              NaN                              NaN  E92000001
# 10             NaN                              NaN  E92000001
# 11             NaN                              NaN  E92000001
# 12             NaN                              NaN  E92000001
# 13             NaN                              NaN  E92000001
# 14             NaN                              NaN  E92000001
# 15             NaN                              NaN  E92000001
# 16             NaN                              NaN  E92000001
# 17             NaN                              NaN  E92000001
# 18             NaN                              NaN  E92000001
# 19             NaN                              NaN  E92000001
# 20             NaN                              NaN  E92000001
# 21             NaN                              NaN  E92000001
# 22             NaN                              NaN  E92000001
# 23             NaN                              NaN  E92000001
# 24             NaN                              NaN  E92000001
# 25             NaN                              NaN  E92000001
# 26             NaN                              NaN  E92000001
# 27             NaN                              NaN  E92000001
# 28             NaN                              NaN  E92000001
# 29             NaN                              NaN  E92000001
# ...            ...                              ...        ...
# 104150   E12000007                    London region  E09000031
# 104151   E12000007                    London region  E09000032
# 104152   E12000007                    London region  E09000033
# 104153   E12000008                South East region  E10000002
# 104154   E12000006           East of England region  E10000003
# 104155   E12000002                North West region  E10000006
# 104156   E12000004             East Midlands region  E10000007
# 104157   E12000009                South West region  E10000008
# 104158   E12000009                South West region  E10000009
# 104159   E12000008                South East region  E10000011
# 104160   E12000006           East of England region  E10000012
# 104161   E12000009                South West region  E10000013
# 104162   E12000008                South East region  E10000014
# 104163   E12000006           East of England region  E10000015
# 104164   E12000008                South East region  E10000016
# 104165   E12000002                North West region  E10000017
# 104166   E12000004             East Midlands region  E10000018
# 104167   E12000004             East Midlands region  E10000019
# 104168   E12000006           East of England region  E10000020
# 104169   E12000004             East Midlands region  E10000021
# 104170   E12000003  Yorkshire and the Humber region  E10000023
# 104171   E12000004             East Midlands region  E10000024
# 104172   E12000008                South East region  E10000025
# 104173   E12000009                South West region  E10000027
# 104174   E12000005             West Midlands region  E10000028
# 104175   E12000006           East of England region  E10000029
# 104176   E12000008                South East region  E10000030
# 104177   E12000005             West Midlands region  E10000031
# 104178   E12000008                South East region  E10000032
# 104179   E12000005             West Midlands region  E10000034
#
#                Area Name    Area Type      Sex       Age  \
# 0                England      England     Male  All ages
# 1                England      England     Male  All ages
# 2                England      England     Male  All ages
# 3                England      England     Male  All ages
# 4                England      England     Male  All ages
# 5                England      England     Male  All ages
# 6                England      England     Male  All ages
# 7                England      England     Male  All ages
# 8                England      England     Male  All ages
# 9                England      England     Male  All ages
# 10               England      England     Male  All ages
# 11               England      England     Male  All ages
# 12               England      England     Male  All ages
# 13               England      England     Male  All ages
# 14               England      England     Male  All ages
# 15               England      England     Male  All ages
# 16               England      England     Male  All ages
# 17               England      England     Male  All ages
# 18               England      England     Male  All ages
# 19               England      England     Male  All ages
# 20               England      England     Male  All ages
# 21               England      England   Female  All ages
# 22               England      England   Female  All ages
# 23               England      England   Female  All ages
# 24               England      England   Female  All ages
# 25               England      England   Female  All ages
# 26               England      England   Female  All ages
# 27               England      England   Female  All ages
# 28               England      England   Female  All ages
# 29               England      England   Female  All ages
# ...                  ...          ...      ...       ...
# 104150    Waltham Forest  County & UA  Persons   18+ yrs
# 104151        Wandsworth  County & UA  Persons   18+ yrs
# 104152       Westminster  County & UA  Persons   18+ yrs
# 104153   Buckinghamshire  County & UA  Persons   18+ yrs
# 104154    Cambridgeshire  County & UA  Persons   18+ yrs
# 104155           Cumbria  County & UA  Persons   18+ yrs
# 104156        Derbyshire  County & UA  Persons   18+ yrs
# 104157             Devon  County & UA  Persons   18+ yrs
# 104158            Dorset  County & UA  Persons   18+ yrs
# 104159       East Sussex  County & UA  Persons   18+ yrs
# 104160             Essex  County & UA  Persons   18+ yrs
# 104161   Gloucestershire  County & UA  Persons   18+ yrs
# 104162         Hampshire  County & UA  Persons   18+ yrs
# 104163     Hertfordshire  County & UA  Persons   18+ yrs
# 104164              Kent  County & UA  Persons   18+ yrs
# 104165        Lancashire  County & UA  Persons   18+ yrs
# 104166    Leicestershire  County & UA  Persons   18+ yrs
# 104167      Lincolnshire  County & UA  Persons   18+ yrs
# 104168           Norfolk  County & UA  Persons   18+ yrs
# 104169  Northamptonshire  County & UA  Persons   18+ yrs
# 104170   North Yorkshire  County & UA  Persons   18+ yrs
# 104171   Nottinghamshire  County & UA  Persons   18+ yrs
# 104172       Oxfordshire  County & UA  Persons   18+ yrs
# 104173          Somerset  County & UA  Persons   18+ yrs
# 104174     Staffordshire  County & UA  Persons   18+ yrs
# 104175           Suffolk  County & UA  Persons   18+ yrs
# 104176            Surrey  County & UA  Persons   18+ yrs
# 104177      Warwickshire  County & UA  Persons   18+ yrs
# 104178       West Sussex  County & UA  Persons   18+ yrs
# 104179    Worcestershire  County & UA  Persons   18+ yrs
#
#                                             Category Type       ...         \
# 0                                                     NaN       ...
# 1       County & UA deprivation deciles in England (IM...       ...
# 2       County & UA deprivation deciles in England (IM...       ...
# 3       County & UA deprivation deciles in England (IM...       ...
# 4       County & UA deprivation deciles in England (IM...       ...
# 5       County & UA deprivation deciles in England (IM...       ...
# 6       County & UA deprivation deciles in England (IM...       ...
# 7       County & UA deprivation deciles in England (IM...       ...
# 8       County & UA deprivation deciles in England (IM...       ...
# 9       County & UA deprivation deciles in England (IM...       ...
# 10      County & UA deprivation deciles in England (IM...       ...
# 11      District & UA deprivation deciles in England (...       ...
# 12      District & UA deprivation deciles in England (...       ...
# 13      District & UA deprivation deciles in England (...       ...
# 14      District & UA deprivation deciles in England (...       ...
# 15      District & UA deprivation deciles in England (...       ...
# 16      District & UA deprivation deciles in England (...       ...
# 17      District & UA deprivation deciles in England (...       ...
# 18      District & UA deprivation deciles in England (...       ...
# 19      District & UA deprivation deciles in England (...       ...
# 20      District & UA deprivation deciles in England (...       ...
# 21                                                    NaN       ...
# 22      County & UA deprivation deciles in England (IM...       ...
# 23      County & UA deprivation deciles in England (IM...       ...
# 24      County & UA deprivation deciles in England (IM...       ...
# 25      County & UA deprivation deciles in England (IM...       ...
# 26      County & UA deprivation deciles in England (IM...       ...
# 27      County & UA deprivation deciles in England (IM...       ...
# 28      County & UA deprivation deciles in England (IM...       ...
# 29      County & UA deprivation deciles in England (IM...       ...
# ...                                                   ...       ...
# 104150                                                NaN       ...
# 104151                                                NaN       ...
# 104152                                                NaN       ...
# 104153                                                NaN       ...
# 104154                                                NaN       ...
# 104155                                                NaN       ...
# 104156                                                NaN       ...
# 104157                                                NaN       ...
# 104158                                                NaN       ...
# 104159                                                NaN       ...
# 104160                                                NaN       ...
# 104161                                                NaN       ...
# 104162                                                NaN       ...
# 104163                                                NaN       ...
# 104164                                                NaN       ...
# 104165                                                NaN       ...
# 104166                                                NaN       ...
# 104167                                                NaN       ...
# 104168                                                NaN       ...
# 104169                                                NaN       ...
# 104170                                                NaN       ...
# 104171                                                NaN       ...
# 104172                                                NaN       ...
# 104173                                                NaN       ...
# 104174                                                NaN       ...
# 104175                                                NaN       ...
# 104176                                                NaN       ...
# 104177                                                NaN       ...
# 104178                                                NaN       ...
# 104179                                                NaN       ...
#
#        Upper CI 99.8 limit          Count  Denominator  \
# 0                      NaN  185985.160125   25434926.0
# 1                      NaN   20083.051469    2338527.0
# 2                      NaN   14510.012802    1705740.0
# 3                      NaN   14100.592626    1768016.0
# 4                      NaN   19561.638203    2455500.0
# 5                      NaN   13388.960624    1813235.0
# 6                      NaN   21994.552990    2743376.0
# 7                      NaN   23221.531396    3411509.0
# 8                      NaN   21218.300337    3145237.0
# 9                      NaN   19624.380483    2990348.0
# 10                     NaN   15870.521779    3063438.0
# 11                     NaN   33043.791633    3865642.0
# 12                     NaN   30111.413570    3738924.0
# 13                     NaN   26542.781074    3419448.0
# 14                     NaN   17972.900720    2266453.0
# 15                     NaN   16231.361658    2273988.0
# 16                     NaN   15392.760371    2339545.0
# 17                     NaN   13131.699272    2056519.0
# 18                     NaN   11217.623096    1823353.0
# 19                     NaN   11327.534900    1986405.0
# 20                     NaN    8601.676415    1664649.0
# 21                     NaN  113022.942218   26380927.0
# 22                     NaN   10771.455553    2395085.0
# 23                     NaN    8516.319044    1757441.0
# 24                     NaN    8401.824251    1814843.0
# 25                     NaN   11804.507075    2548598.0
# 26                     NaN    8190.917309    1887745.0
# 27                     NaN   13185.645528    2851726.0
# 28                     NaN   14757.659779    3548267.0
# 29                     NaN   14390.769699    3295367.0
# ...                    ...            ...          ...
# 104150                 NaN    2948.230000     203724.0
# 104151                 NaN    3742.940000     252442.0
# 104152                 NaN    2728.050000     192598.0
# 104153                 NaN    3487.970000     403013.0
# 104154                 NaN    5577.720000     508328.0
# 104155                 NaN    5833.620000     404581.0
# 104156                 NaN    8534.300000     625782.0
# 104157                 NaN    7094.650000     623151.0
# 104158                 NaN    3491.950000     341035.0
# 104159                 NaN    5296.830000     434374.0
# 104160                 NaN   12205.220000    1131693.0
# 104161                 NaN    5193.560000     487526.0
# 104162                 NaN    9980.440000    1064677.0
# 104163                 NaN    8660.550000     893020.0
# 104164                 NaN   14052.040000    1182104.0
# 104165                 NaN   14199.260000     939980.0
# 104166                 NaN    5180.010000     533105.0
# 104167                 NaN    6807.250000     590137.0
# 104168                 NaN    9195.390000     710629.0
# 104169                 NaN    6535.390000     553700.0
# 104170                 NaN    5340.130000     484157.0
# 104171                 NaN    8345.980000     638312.0
# 104172                 NaN    5373.150000     531363.0
# 104173                 NaN    5057.670000     432710.0
# 104174                 NaN    8451.000000     690562.0
# 104175                 NaN    6570.940000     587180.0
# 104176                 NaN    7772.840000     906670.0
# 104177                 NaN    4937.160000     439332.0
# 104178                 NaN    6966.730000     659564.0
# 104179                 NaN    5407.140000     460490.0
#
#                                            Value note          Recent Trend  \
# 0                                                 NaN                   NaN
# 1       Value for Hackney and City of London combined                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5       Value for Cornwall & Isles of Scilly combined                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9       Value for Hackney and City of London combined                   NaN
# 10      Value for Cornwall & Isles of Scilly combined                   NaN
# 11      Value for Hackney and City of London combined                   NaN
# 12                                                NaN                   NaN
# 13      Value for Cornwall & Isles of Scilly combined                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18      Value for Hackney and City of London combined                   NaN
# 19      Value for Cornwall & Isles of Scilly combined                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22      Value for Hackney and City of London combined                   NaN
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25                                                NaN                   NaN
# 26      Value for Cornwall & Isles of Scilly combined                   NaN
# 27                                                NaN                   NaN
# 28                                                NaN                   NaN
# 29                                                NaN                   NaN
# ...                                               ...                   ...
# 104150                                            NaN  Cannot be calculated
# 104151                                            NaN  Cannot be calculated
# 104152                                            NaN  Cannot be calculated
# 104153                                            NaN  Cannot be calculated
# 104154                                            NaN  Cannot be calculated
# 104155                                            NaN  Cannot be calculated
# 104156                                            NaN  Cannot be calculated
# 104157                                            NaN  Cannot be calculated
# 104158                                            NaN  Cannot be calculated
# 104159                                            NaN  Cannot be calculated
# 104160                                            NaN  Cannot be calculated
# 104161                                            NaN  Cannot be calculated
# 104162                                            NaN  Cannot be calculated
# 104163                                            NaN  Cannot be calculated
# 104164                                            NaN  Cannot be calculated
# 104165                                            NaN  Cannot be calculated
# 104166                                            NaN  Cannot be calculated
# 104167                                            NaN  Cannot be calculated
# 104168                                            NaN  Cannot be calculated
# 104169                                            NaN  Cannot be calculated
# 104170                                            NaN  Cannot be calculated
# 104171                                            NaN  Cannot be calculated
# 104172                                            NaN  Cannot be calculated
# 104173                                            NaN  Cannot be calculated
# 104174                                            NaN  Cannot be calculated
# 104175                                            NaN  Cannot be calculated
# 104176                                            NaN  Cannot be calculated
# 104177                                            NaN  Cannot be calculated
# 104178                                            NaN  Cannot be calculated
# 104179                                            NaN  Cannot be calculated
#
#         Compared to England value or percentiles  \
# 0                                   Not compared
# 1                                          Worse
# 2                                          Worse
# 3                                          Worse
# 4                                          Worse
# 5                                        Similar
# 6                                          Worse
# 7                                         Better
# 8                                         Better
# 9                                         Better
# 10                                        Better
# 11                                         Worse
# 12                                         Worse
# 13                                         Worse
# 14                                         Worse
# 15                                        Better
# 16                                        Better
# 17                                        Better
# 18                                        Better
# 19                                        Better
# 20                                        Better
# 21                                  Not compared
# 22                                         Worse
# 23                                         Worse
# 24                                         Worse
# 25                                         Worse
# 26                                       Similar
# 27                                         Worse
# 28                                        Better
# 29                                       Similar
# ...                                          ...
# 104150                                   Similar
# 104151                                   Similar
# 104152                                   Similar
# 104153                                    Better
# 104154                                   Similar
# 104155                                   Similar
# 104156                                   Similar
# 104157                                   Similar
# 104158                                   Similar
# 104159                                   Similar
# 104160                                   Similar
# 104161                                   Similar
# 104162                                    Better
# 104163                                    Better
# 104164                                   Similar
# 104165                                   Similar
# 104166                                   Similar
# 104167                                   Similar
# 104168                                   Similar
# 104169                                   Similar
# 104170                                   Similar
# 104171                                   Similar
# 104172                                   Similar
# 104173                                   Similar
# 104174                                   Similar
# 104175                                   Similar
# 104176                                    Better
# 104177                                   Similar
# 104178                                   Similar
# 104179                                   Similar
#
#         Compared to Region value or percentiles  Time period Sortable  \
# 0                                  Not compared              20080000
# 1                                  Not compared              20080000
# 2                                  Not compared              20080000
# 3                                  Not compared              20080000
# 4                                  Not compared              20080000
# 5                                  Not compared              20080000
# 6                                  Not compared              20080000
# 7                                  Not compared              20080000
# 8                                  Not compared              20080000
# 9                                  Not compared              20080000
# 10                                 Not compared              20080000
# 11                                 Not compared              20080000
# 12                                 Not compared              20080000
# 13                                 Not compared              20080000
# 14                                 Not compared              20080000
# 15                                 Not compared              20080000
# 16                                 Not compared              20080000
# 17                                 Not compared              20080000
# 18                                 Not compared              20080000
# 19                                 Not compared              20080000
# 20                                 Not compared              20080000
# 21                                 Not compared              20080000
# 22                                 Not compared              20080000
# 23                                 Not compared              20080000
# 24                                 Not compared              20080000
# 25                                 Not compared              20080000
# 26                                 Not compared              20080000
# 27                                 Not compared              20080000
# 28                                 Not compared              20080000
# 29                                 Not compared              20080000
# ...                                         ...                   ...
# 104150                                  Similar              20140000
# 104151                                  Similar              20140000
# 104152                                  Similar              20140000
# 104153                                  Similar              20140000
# 104154                                  Similar              20140000
# 104155                                   Better              20140000
# 104156                                  Similar              20140000
# 104157                                  Similar              20140000
# 104158                                  Similar              20140000
# 104159                                  Similar              20140000
# 104160                                  Similar              20140000
# 104161                                  Similar              20140000
# 104162                                  Similar              20140000
# 104163                                  Similar              20140000
# 104164                                  Similar              20140000
# 104165                                  Similar              20140000
# 104166                                  Similar              20140000
# 104167                                  Similar              20140000
# 104168                                  Similar              20140000
# 104169                                  Similar              20140000
# 104170                                   Better              20140000
# 104171                                  Similar              20140000
# 104172                                  Similar              20140000
# 104173                                  Similar              20140000
# 104174                                  Similar              20140000
# 104175                                  Similar              20140000
# 104176                                  Similar              20140000
# 104177                                  Similar              20140000
# 104178                                  Similar              20140000
# 104179                                  Similar              20140000
#
#         New data Compared to goal
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# 5            NaN              NaN
# 6            NaN              NaN
# 7            NaN              NaN
# 8            NaN              NaN
# 9            NaN              NaN
# 10           NaN              NaN
# 11           NaN              NaN
# 12           NaN              NaN
# 13           NaN              NaN
# 14           NaN              NaN
# 15           NaN              NaN
# 16           NaN              NaN
# 17           NaN              NaN
# 18           NaN              NaN
# 19           NaN              NaN
# 20           NaN              NaN
# 21           NaN              NaN
# 22           NaN              NaN
# 23           NaN              NaN
# 24           NaN              NaN
# 25           NaN              NaN
# 26           NaN              NaN
# 27           NaN              NaN
# 28           NaN              NaN
# 29           NaN              NaN
# ...          ...              ...
# 104150       NaN              NaN
# 104151       NaN              NaN
# 104152       NaN              NaN
# 104153       NaN              NaN
# 104154       NaN              NaN
# 104155       NaN              NaN
# 104156       NaN              NaN
# 104157       NaN              NaN
# 104158       NaN              NaN
# 104159       NaN              NaN
# 104160       NaN              NaN
# 104161       NaN              NaN
# 104162       NaN              NaN
# 104163       NaN              NaN
# 104164       NaN              NaN
# 104165       NaN              NaN
# 104166       NaN              NaN
# 104167       NaN              NaN
# 104168       NaN              NaN
# 104169       NaN              NaN
# 104170       NaN              NaN
# 104171       NaN              NaN
# 104172       NaN              NaN
# 104173       NaN              NaN
# 104174       NaN              NaN
# 104175       NaN              NaN
# 104176       NaN              NaN
# 104177       NaN              NaN
# 104178       NaN              NaN
# 104179       NaN              NaN
#
# [104180 rows x 26 columns]

# %%
table.rename(index=str,
               columns={
                   'Indicator ID':'Indicator',
                   'Area Code' :'Geography',
                   'Time period':'Period',
                   'Upper CI 95.0 limit': 'CI Upper',
                   'Lower CI 95.0 limit': 'CI Lower'
               }, inplace = True)
table.count()
# Out:
# Indicator                                   104180
# Indicator Name                              104180
# Parent Code                                  92140
# Parent Name                                  92140
# Geography                                   104180
# Area Name                                   104180
# Area Type                                   104180
# Sex                                         104180
# Age                                         104180
# Category Type                                11462
# Category                                     11462
# Period                                      104180
# Value                                       101459
# CI Lower                                    100816
# CI Upper                                    100816
# Lower CI 99.8 limit                          38553
# Upper CI 99.8 limit                          38553
# Count                                       101789
# Denominator                                 101939
# Value note                                    7391
# Recent Trend                                 12122
# Compared to England value or percentiles    104180
# Compared to Region value or percentiles     104180
# Time period Sortable                        104180
# New data                                         0
# Compared to goal                                 0
# dtype: int64

# %%
table = table[table['Category Type'].isnull() == True]
table = table.dropna(subset=['Value'])
table.count()
# Out:
# Indicator                                   90514
# Indicator Name                              90514
# Parent Code                                 89942
# Parent Name                                 89942
# Geography                                   90514
# Area Name                                   90514
# Area Type                                   90514
# Sex                                         90514
# Age                                         90514
# Category Type                                   0
# Category                                        0
# Period                                      90514
# Value                                       90514
# CI Lower                                    90013
# CI Upper                                    90013
# Lower CI 99.8 limit                         34399
# Upper CI 99.8 limit                         34399
# Count                                       90037
# Denominator                                 89553
# Value note                                   1059
# Recent Trend                                10655
# Compared to England value or percentiles    90514
# Compared to Region value or percentiles     90514
# Time period Sortable                        90514
# New data                                        0
# Compared to goal                                0
# dtype: int64

# %%
table = table[['Geography','Period','Sex', 'Age','Indicator',\
                       'Value','CI Upper','CI Lower']]

# %%
table['Sex'] = table['Sex'].map(
    lambda x: {
        'Female' : 'F', 
        'Male' : 'M',
        'Persons': 'T' ,
        }.get(x, x))

# %%
table['Period'] = table['Period'].map(
    lambda x: {
        '2008/09' : 'gregorian-interval/2008-04-01T00:00:00/P1Y',
        '2009/10' : 'gregorian-interval/2009-04-01T00:00:00/P1Y', 
        '2010/11' : 'gregorian-interval/2010-04-01T00:00:00/P1Y', 
        '2011/12' : 'gregorian-interval/2011-04-01T00:00:00/P1Y', 
        '2012/13' : 'gregorian-interval/2012-04-01T00:00:00/P1Y', 
        '2013/14' : 'gregorian-interval/2013-04-01T00:00:00/P1Y',
        '2014/15' :'gregorian-interval/2014-04-01T00:00:00/P1Y', 
        '2015/16' : 'gregorian-interval/2015-04-01T00:00:00/P1Y', 
        '2016/17' : 'gregorian-interval/2016-04-01T00:00:00/P1Y', 
        '2017/18' :'gregorian-interval/2017-04-01T00:00:00/P1Y', 
        '2006/07 - 08/09': 'gregorian-interval/2006-04-01T00:00:00/P3Y',
       '2007/08 - 09/10' : 'gregorian-interval/2007-04-01T00:00:00/P3Y', 
        '2008/09 - 10/11': 'gregorian-interval/2008-04-01T00:00:00/P3Y', 
        '2009/10 - 11/12': 'gregorian-interval/2009-04-01T00:00:00/P3Y',
       '2010/11 - 12/13': 'gregorian-interval/2010-04-01T00:00:00/P3Y', 
        '2011/12 - 13/14': 'gregorian-interval/2011-04-01T00:00:00/P3Y', 
        '2012/13 - 14/15': 'gregorian-interval/2012-04-01T00:00:00/P3Y',
       '2013/14 - 15/16': 'gregorian-interval/2013-04-01T00:00:00/P3Y', 
        '2014/15 - 16/17': 'gregorian-interval/2014-04-01T00:00:00/P3Y', 
        '2015/16 - 17/18': 'gregorian-interval/2015-04-01T00:00:00/P3Y', 
        '2008' : 'year/2008',
       '2009': 'year/2009', '2010': 'year/2010', '2011': 'year/2011', '2012': 'year/2012', 
        '2013': 'year/2013', '2014': 'year/2014', '2015': 'year/2015', '2016': 'year/2016',
       '2017': 'year/2017', 
        '2006 - 08' :'gregorian-interval/2006-01-01T00:00:00/P2Y', 
        '2007 - 09' :'gregorian-interval/2007-01-01T00:00:00/P2Y', 
        '2008 - 10': 'gregorian-interval/2008-01-01T00:00:00/P2Y', 
        '2009 - 11' :'gregorian-interval/2009-01-01T00:00:00/P2Y',
       '2010 - 12': 'gregorian-interval/2010-01-01T00:00:00/P2Y', 
        '2011 - 13': 'gregorian-interval/2011-01-01T00:00:00/P2Y', 
        '2012 - 14' :'gregorian-interval/2012-01-01T00:00:00/P2Y', 
        '2013 - 15' : 'gregorian-interval/2013-01-01T00:00:00/P2Y', 
        '2014 - 16' :'gregorian-interval/2014-01-01T00:00:00/P2Y',
       '2015 - 17':'gregorian-interval/2015-01-01T00:00:00/P2Y', 
        '2004 - 06' :'gregorian-interval/2004-01-01T00:00:00/P2Y', 
        '2005 - 07': 'gregorian-interval/2005-01-01T00:00:00/P2Y', 
        '2011 - 14' : 'gregorian-interval/2011-01-01T00:00:00/P3Y'       
        }.get(x, x))

# %%
table['Age'].unique()
# Out:
# array(['All ages', '<18 yrs', '<75 yrs', '<40 yrs', '40-64 yrs',
#        '65+ yrs', '16+ yrs', '16-64 yrs (M), 16-61 yrs (F)', '17+ yrs',
#        '18+ yrs'], dtype=object)

# %%
table['Age'] = table['Age'].map(
    lambda x: {
        'All ages' : 'all', 
        '<18 yrs' : 'under-18', 
        '<75 yrs' : 'under-75', 
        '<40 yrs' : 'under-40', 
        '40-64 yrs' : '40-64',
        '65+ yrs' : 'ag1/65-plus', 
        '16+ yrs' : '16-plus', 
        '16-64 yrs (M), 16-61 yrs (F)' : 'agr/16-61-or-64',
        '17+ yrs' : '17-plus',
        '18+ yrs' : '18-plus', 
        '18-75 yrs' : "18-75 yrs"        
        }.get(x, x))

# %%
def user_perc(x):
    
    if str(x) == '91917':
        return 'Rate per 1,000 accidents'
    elif ((str(x) ==  '91182') | (str(x) == '92772')) :
        return 'Count'
    elif ((str(x) ==  '92447') | (str(x) == '91123') | (str(x) == '92774') |\
         (str(x) ==  '92776') | (str(x) == '92778') | (str(x) == '93193')) :
        return 'Percentage'
    elif ((str(x) ==  '92763') | (str(x) == '92765') | (str(x) == '92768') | (str(x) ==  '92770')) :
        return 'Volume'   
    else:
        return 'Rate per 100,000 persons'    
table['Measure Type'] = table.apply(lambda row: user_perc(row['Indicator']), axis = 1)

# %%
def user_perc(x):
    
    if str(x) == '92772':
        return 'premises-licensed-per-sq-km'
    elif ((str(x) ==  '92763') | (str(x) == '92765') | (str(x) == '92768') | (str(x) ==  '92770')) :
        return 'litres-alcohol-per-adult'   
    else:
        return 'people'    
table['Unit'] = table.apply(lambda row: user_perc(row['Indicator']), axis = 1)

# %%
table = table[['Geography','Period','Sex', 'Age','Indicator',\
                       'Value','Measure Type','Unit', 'CI Lower','CI Upper']]

# %%
out = Path('out')
out.mkdir(exist_ok=True, parents=True)
table.drop_duplicates().to_csv(out / 'observations.csv', index = False)

# %%
scraper.dataset.family = 'health'
scraper.dataset.theme = THEME['health-social-care']
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())

# %%
table
# Out:
#         Geography                                      Period Sex      Age  \
# 0       E92000001  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 21      E92000001  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 42      E92000001  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 63      E12000001  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 64      E12000002  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 65      E12000003  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 66      E12000004  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 67      E12000005  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 68      E12000006  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 69      E12000007  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 70      E12000008  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 71      E12000009  gregorian-interval/2008-04-01T00:00:00/P1Y   M      all
# 72      E12000001  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 73      E12000002  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 74      E12000003  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 75      E12000004  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 76      E12000005  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 77      E12000006  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 78      E12000007  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 79      E12000008  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 80      E12000009  gregorian-interval/2008-04-01T00:00:00/P1Y   F      all
# 81      E12000001  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 82      E12000002  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 83      E12000003  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 84      E12000004  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 85      E12000005  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 86      E12000006  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 87      E12000007  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 88      E12000008  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# 89      E12000009  gregorian-interval/2008-04-01T00:00:00/P1Y   T      all
# ...           ...                                         ...  ..      ...
# 104150  E09000031  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104151  E09000032  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104152  E09000033  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104153  E10000002  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104154  E10000003  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104155  E10000006  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104156  E10000007  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104157  E10000008  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104158  E10000009  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104159  E10000011  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104160  E10000012  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104161  E10000013  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104162  E10000014  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104163  E10000015  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104164  E10000016  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104165  E10000017  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104166  E10000018  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104167  E10000019  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104168  E10000020  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104169  E10000021  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104170  E10000023  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104171  E10000024  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104172  E10000025  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104173  E10000027  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104174  E10000028  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104175  E10000029  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104176  E10000030  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104177  E10000031  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104178  E10000032  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
# 104179  E10000034  gregorian-interval/2014-04-01T00:00:00/P1Y   T  18-plus
#
#         Indicator        Value              Measure Type    Unit     CI Lower  \
# 0           91414   793.263506  Rate per 100,000 persons  people   789.571167
# 21          91414   440.472111  Rate per 100,000 persons  people   437.890656
# 42          91414   605.754207  Rate per 100,000 persons  people   603.565568
# 63          91414  1050.579307  Rate per 100,000 persons  people  1031.891527
# 64          91414   970.816892  Rate per 100,000 persons  people   959.746226
# 65          91414   776.168682  Rate per 100,000 persons  people   764.716922
# 66          91414   826.323598  Rate per 100,000 persons  people   813.618393
# 67          91414   860.647074  Rate per 100,000 persons  people   848.881539
# 68          91414   630.091761  Rate per 100,000 persons  people   620.293219
# 69          91414   731.968931  Rate per 100,000 persons  people   721.688781
# 70          91414   648.161785  Rate per 100,000 persons  people   639.970788
# 71          91414   788.533108  Rate per 100,000 persons  people   777.345445
# 72          91414   622.087856  Rate per 100,000 persons  people   608.584909
# 73          91414   491.773349  Rate per 100,000 persons  people   484.408653
# 74          91414   471.734604  Rate per 100,000 persons  people   463.332825
# 75          91414   493.717741  Rate per 100,000 persons  people   484.456879
# 76          91414   502.070771  Rate per 100,000 persons  people   493.588133
# 77          91414   367.514076  Rate per 100,000 persons  people   360.477199
# 78          91414   354.021327  Rate per 100,000 persons  people   347.527614
# 79          91414   356.967341  Rate per 100,000 persons  people   351.259386
# 80          91414   478.289671  Rate per 100,000 persons  people   469.974548
# 81          91414   822.692918  Rate per 100,000 persons  people   811.460006
# 82          91414   717.566921  Rate per 100,000 persons  people   711.125200
# 83          91414   613.687489  Rate per 100,000 persons  people   606.778261
# 84          91414   649.769234  Rate per 100,000 persons  people   642.106135
# 85          91414   670.600523  Rate per 100,000 persons  people   663.527972
# 86          91414   490.116550  Rate per 100,000 persons  people   484.240826
# 87          91414   530.345749  Rate per 100,000 persons  people   524.496300
# 88          91414   492.753353  Rate per 100,000 persons  people   487.897736
# 89          91414   622.817730  Rate per 100,000 persons  people   615.997472
# ...           ...          ...                       ...     ...          ...
# 104150      93193     1.450000                Percentage  people     1.090000
# 104151      93193     1.480000                Percentage  people     1.160000
# 104152      93193     1.420000                Percentage  people     1.110000
# 104153      93193     0.870000                Percentage  people     0.620000
# 104154      93193     1.100000                Percentage  people     0.830000
# 104155      93193     1.440000                Percentage  people     1.150000
# 104156      93193     1.360000                Percentage  people     1.090000
# 104157      93193     1.140000                Percentage  people     0.840000
# 104158      93193     1.020000                Percentage  people     0.780000
# 104159      93193     1.220000                Percentage  people     0.950000
# 104160      93193     1.080000                Percentage  people     0.790000
# 104161      93193     1.070000                Percentage  people     0.790000
# 104162      93193     0.940000                Percentage  people     0.670000
# 104163      93193     0.970000                Percentage  people     0.710000
# 104164      93193     1.190000                Percentage  people     0.890000
# 104165      93193     1.510000                Percentage  people     1.200000
# 104166      93193     0.970000                Percentage  people     0.700000
# 104167      93193     1.150000                Percentage  people     0.840000
# 104168      93193     1.290000                Percentage  people     1.030000
# 104169      93193     1.180000                Percentage  people     0.900000
# 104170      93193     1.100000                Percentage  people     0.860000
# 104171      93193     1.310000                Percentage  people     1.040000
# 104172      93193     1.010000                Percentage  people     0.730000
# 104173      93193     1.170000                Percentage  people     0.890000
# 104174      93193     1.220000                Percentage  people     0.950000
# 104175      93193     1.120000                Percentage  people     0.840000
# 104176      93193     0.860000                Percentage  people     0.610000
# 104177      93193     1.120000                Percentage  people     0.860000
# 104178      93193     1.060000                Percentage  people     0.810000
# 104179      93193     1.170000                Percentage  people     0.910000
#
#            CI Upper
# 0        796.968513
# 21       443.064933
# 42       607.948765
# 63      1069.514712
# 64       981.980814
# 65       787.745557
# 66       839.173873
# 67       872.532201
# 68       640.004077
# 69       742.350611
# 70       656.429972
# 71       799.840168
# 72       635.813878
# 73       499.221513
# 74       480.249827
# 75       503.110409
# 76       510.662015
# 77       374.653203
# 78       360.602041
# 79       362.744310
# 80       486.714198
# 81       834.041671
# 82       724.052127
# 83       620.655287
# 84       657.500446
# 85       677.729277
# 86       496.045464
# 87       536.241618
# 88       497.645001
# 89       629.694413
# ...             ...
# 104150     2.040000
# 104151     2.020000
# 104152     1.900000
# 104153     1.260000
# 104154     1.510000
# 104155     1.860000
# 104156     1.780000
# 104157     1.620000
# 104158     1.400000
# 104159     1.630000
# 104160     1.520000
# 104161     1.490000
# 104162     1.340000
# 104163     1.380000
# 104164     1.640000
# 104165     1.980000
# 104166     1.390000
# 104167     1.630000
# 104168     1.700000
# 104169     1.600000
# 104170     1.480000
# 104171     1.720000
# 104172     1.450000
# 104173     1.610000
# 104174     1.640000
# 104175     1.550000
# 104176     1.250000
# 104177     1.530000
# 104178     1.440000
# 104179     1.570000
#
# [90514 rows x 10 columns]
